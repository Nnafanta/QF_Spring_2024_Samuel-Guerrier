# %%
import pandas as pd
import yfinance as yf
import datetime as dt

# list of assets (updated with our chosen assets):
# Companies: Salesforce, HP, Lenovo, Ford, Tesla, Walmart, Target 
my_tickers = ['CRM', 'HPQ', 'LNVGY', 'F', 'TSLA', 'WMT', 'TGT']


# Assign a start date and end date for the data download, 1 year of data
start_date = dt.datetime.today() - pd.Timedelta(400, "d")
end_date = dt.datetime.today()

# %%
## Now download the data using the above variables, my_port is short for my portfolio
my_port = yf.download(start=start_date, end=end_date, tickers=my_tickers)
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [********************* 43%%                      ]  3 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************57%%*                     ]  4 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************71%%********              ]  5 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  7 of 7 completed

# %%
## And review the data:
my_port.head()
# Out:
# Price        Adj Close                                               \
# Ticker             CRM          F        HPQ      LNVGY         TGT
# Date
# 2023-02-09  173.433456  11.887389  28.355570  16.523762  164.779068
# 2023-02-10  166.812103  11.924858  28.651932  16.035515  163.480988
# 2023-02-13  170.856812  12.262090  29.005665  16.198263  166.654053
# 2023-02-14  169.738281  12.149679  29.063025  16.246130  165.618744
# 2023-02-15  170.876801  12.112209  29.187309  16.179115  170.311462
#
# Price                                   Close                    ...  \
# Ticker            TSLA        WMT         CRM      F        HPQ  ...
# Date                                                             ...
# 2023-02-09  207.320007  46.306904  173.660004  13.49  29.660000  ...
# 2023-02-10  196.889999  47.026772  167.029999  12.73  29.969999  ...
# 2023-02-13  194.639999  47.743359  171.080002  13.09  30.340000  ...
# 2023-02-14  209.250000  47.605934  169.960007  12.97  30.400000  ...
# 2023-02-15  214.240005  47.959320  171.100006  12.93  30.530001  ...
#
# Price             Open                             Volume              \
# Ticker             TGT        TSLA        WMT         CRM           F
# Date
# 2023-02-09  172.699997  207.779999  46.956669  11512300.0  78667100.0
# 2023-02-10  170.320007  202.229996  47.696667  11273700.0  68205200.0
# 2023-02-13  170.990005  194.419998  48.236668   8820300.0  64201900.0
# 2023-02-14  171.550003  191.940002  48.576668   8393100.0  75352900.0
# 2023-02-15  170.009995  211.759995  48.320000   4997000.0  65850000.0
#
# Price
# Ticker            HPQ  LNVGY        TGT         TSLA       WMT
# Date
# 2023-02-09  3726400.0  46400  1656100.0  215431400.0  13064400
# 2023-02-10  4136700.0  64500  1841400.0  204754100.0  15002700
# 2023-02-13  4280900.0  24400  2432600.0  172475500.0  16015800
# 2023-02-14  5647800.0  59400  2418400.0  216455700.0  13831200
# 2023-02-15  4269600.0  44400  2954400.0  181006400.0  14674200
#
# [5 rows x 42 columns]

# %%
## We may only need one index of the multi-index that was returned (Adj Close)
my_port = my_port['Adj Close']

my_port.head()
# Out:
# Ticker             CRM          F        HPQ      LNVGY         TGT  \
# Date
# 2023-02-09  173.433456  11.887389  28.355570  16.523762  164.779068
# 2023-02-10  166.812103  11.924858  28.651932  16.035515  163.480988
# 2023-02-13  170.856812  12.262090  29.005665  16.198263  166.654053
# 2023-02-14  169.738281  12.149679  29.063025  16.246130  165.618744
# 2023-02-15  170.876801  12.112209  29.187309  16.179115  170.311462
#
# Ticker            TSLA        WMT
# Date
# 2023-02-09  207.320007  46.306904
# 2023-02-10  196.889999  47.026772
# 2023-02-13  194.639999  47.743359
# 2023-02-14  209.250000  47.605934
# 2023-02-15  214.240005  47.959320

# %%
my_port_table = pd.DataFrame(index = my_tickers)

# %%
## Calculation for 1a. and 1b. in the 1st project. Column of the tickers and portfolio weights.

port_weight = [1/len(my_tickers)] * len(my_tickers)
my_port_table['Portfolio_Weight'] = port_weight

my_port_table
# Out:
#        Portfolio_Weight
# CRM            0.142857
# HPQ            0.142857
# LNVGY          0.142857
# F              0.142857
# TSLA           0.142857
# WMT            0.142857
# TGT            0.142857

# %%
## Calculation for 1c. 
def get_stock_prices(my_tickers, start_date, end_date):
    my_port
    return my_port

stock_prices = get_stock_prices(my_tickers, start_date, end_date)
returns_3months = stock_prices.pct_change().rolling(window=63).sum().dropna()
volatility = returns_3months.std() * (252 ** 0.5)
result_df = pd.DataFrame({'Ticker': my_tickers, 'Volatility': volatility})

print(result_df)
# Out:
#        Ticker  Volatility
# Ticker
# CRM       CRM    2.062737
# F         HPQ    2.364267
# HPQ     LNVGY    1.740426
# LNVGY       F    1.837282
# TGT      TSLA    3.046613
# TSLA      WMT    3.600751
# WMT       TGT    0.831869
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\1654888696.py:7: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_3months = stock_prices.pct_change().rolling(window=63).sum().dropna()

# %%
my_port_table['Annualized Volatility'] = volatility
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility
# CRM            0.142857               2.062737
# HPQ            0.142857               1.740426
# LNVGY          0.142857               1.837282
# F              0.142857               2.364267
# TSLA           0.142857               3.600751
# WMT            0.142857               0.831869
# TGT            0.142857               3.046613

# %%
## Calculation for 1d.

## First download Adjusted Close Price data for S&P 500 ETF
spy = yf.download(start=start_date, end=end_date, tickers='SPY')
spy = spy['Adj Close']

## Combine portfolio and SPY data into a single DataFrame
my_port_and_spy_data = pd.concat([my_port, spy], axis=1)
my_port_and_spy_data.columns = my_tickers + ['SPY']

## Calculate daily returns
my_port_and_spy__d_returns = my_port_and_spy_data.pct_change().dropna()

## Calculate covariance matrix
my_port_and_spy_cov_matrix = my_port_and_spy__d_returns.cov()

## Extract covariances with SPY
cov_with_spy = my_port_and_spy_cov_matrix['SPY'].drop('SPY')  

## Calculate SPY variance
spy_variance = my_port_and_spy_cov_matrix.loc['SPY', 'SPY']

# Calculate beta
betas_spy = cov_with_spy / spy_variance

spy_beta_table = pd.DataFrame({'Tickers': my_tickers, 'Beta': betas_spy})
print(spy_beta_table)


'''
## Then calculate the daily returns of portfolio and S&P 500 ETF
my_port_d_returns = prices.pct_change().dropna()
spy_d_returns = spy.pct_change().dropna()

covariances = my_port_d_returns.covwith(spy_d_returns)
'''
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#       Tickers      Beta
# CRM       CRM  1.269169
# HPQ       HPQ  1.307456
# LNVGY   LNVGY  0.993005
# F           F  0.700173
# TSLA     TSLA  0.785212
# WMT       WMT  2.080648
# TGT       TGT  0.313866
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\1656573448.py:12: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   my_port_and_spy__d_returns = my_port_and_spy_data.pct_change().dropna()
# '\n## Then calculate the daily returns of portfolio and S&P 500 ETF\nmy_port_d_returns = prices.pct_change().dropna()\nspy_d_returns = spy.pct_change().dropna()\n\ncovariances = my_port_d_returns.covwith(spy_d_returns)\n'

# %%
## Resulting table after calculating 1d. 
my_port_table['Beta against SPY'] = betas_spy
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866

# %%
## Calculation for 1e.

## First download Adjusted Close Price data for S&P 500 ETF
iwm = yf.download(start=start_date, end=end_date, tickers='IWM')
iwm = iwm['Adj Close']

## Combine portfolio and IWM data into a single DataFrame
my_port_and_iwm_data = pd.concat([my_port, iwm], axis=1)
my_port_and_iwm_data.columns = my_tickers + ['IWM']

## Calculate daily returns
my_port_and_iwm__d_returns = my_port_and_iwm_data.pct_change().dropna()

## Calculate covariance matrix
my_port_and_iwm_cov_matrix = my_port_and_iwm__d_returns.cov()

## Extract covariances with IWM
cov_with_iwm = my_port_and_iwm_cov_matrix['IWM'].drop('IWM')

## Calculate IWM variance
iwm_variance = my_port_and_iwm_cov_matrix.loc['IWM', 'IWM']

# Calculate beta
betas_iwm = cov_with_iwm / iwm_variance
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\829095071.py:12: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   my_port_and_iwm__d_returns = my_port_and_iwm_data.pct_change().dropna()

# %%
## Resulting table after calculating 1e.
my_port_table['Beta against IWM'] = betas_iwm
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM
# CRM            0.559584
# HPQ            0.940989
# LNVGY          0.607076
# F              0.556419
# TSLA           0.602892
# WMT            1.079655
# TGT            0.127681

# %%
## Calculation for 1f.

## First download Adjusted Close Price data for DIA
dia = yf.download(start=start_date, end=end_date, tickers='DIA')
dia = dia['Adj Close']

## Combine portfolio and DIA data into a single DataFrame
my_port_and_dia_data = pd.concat([my_port, dia], axis=1)
my_port_and_dia_data.columns = my_tickers + ['DIA']

## Calculate daily returns
my_port_and_dia__d_returns = my_port_and_dia_data.pct_change().dropna()

## Calculate covariance matrix
my_port_and_dia_cov_matrix = my_port_and_dia__d_returns.cov()

## Extract covariances with IWM
cov_with_dia = my_port_and_dia_cov_matrix['DIA'].drop('DIA')

## Calculate DIA variance
dia_variance = my_port_and_dia_cov_matrix.loc['DIA', 'DIA']

# Calculate beta
betas_dia = cov_with_dia / dia_variance
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\2933740110.py:12: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   my_port_and_dia__d_returns = my_port_and_dia_data.pct_change().dropna()

# %%
## Resulting table after calculating 1f.
my_port_table['Beta against DIA'] = betas_dia
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM  Beta against DIA
# CRM            0.559584          1.325862
# HPQ            0.940989          1.629387
# LNVGY          0.607076          1.124155
# F              0.556419          0.704999
# TSLA           0.602892          1.093826
# WMT            1.079655          1.832894
# TGT            0.127681          0.440264

# %%
## Calculation of 1g., Average Weekly Drawdown, (52-week Low minus 52-week High) / 52-week High

av_w_drawdown = (my_port.rolling(5).min() - my_port.rolling(5).max()).mean() 

my_port_table['Average Weekly Drawdown'] = av_w_drawdown 
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM  Beta against DIA  Average Weekly Drawdown
# CRM            0.559584          1.325862                -8.166397
# HPQ            0.940989          1.629387                -0.931006
# LNVGY          0.607076          1.124155                -1.209171
# F              0.556419          0.704999                -0.513133
# TSLA           0.602892          1.093826               -14.738930
# WMT            1.079655          1.832894                -1.012800
# TGT            0.127681          0.440264                -5.038657

# %%
## Calculation of 1h., Maximum Weekly Drawdown (52-week Low minus 52-week High) / 52-week High
max_w_drawdown = (my_port.rolling(5).min() - my_port.rolling(5).max()).max()

my_port_table['Maximum Weekly Drawdown'] = max_w_drawdown 
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM  Beta against DIA  Average Weekly Drawdown  \
# CRM            0.559584          1.325862                -8.166397
# HPQ            0.940989          1.629387                -0.931006
# LNVGY          0.607076          1.124155                -1.209171
# F              0.556419          0.704999                -0.513133
# TSLA           0.602892          1.093826               -14.738930
# WMT            1.079655          1.832894                -1.012800
# TGT            0.127681          0.440264                -5.038657
#
#        Maximum Weekly Drawdown
# CRM                  -0.878845
# HPQ                  -0.147306
# LNVGY                -0.229763
# F                    -0.105467
# TSLA                 -3.029999
# WMT                  -0.187992
# TGT                  -0.793396

# %%
## Calculation of 1i., Total Return (using trailing 10-years)

start_date = dt.datetime.today() - pd.Timedelta(3650, "d")  # First, put 3650, which represents 10 years from today.
my_port = yf.download(start=start_date, end=end_date, tickers=my_tickers)  # Then download data for 10 years
my_port = my_port['Adj Close']
t_return = my_port.pct_change().sum()[-20:] # Calculate the yearly returns for each stock, then add up the yearly returns of each stock, then only take into account the last 20 days of data for a trailing calculation
t_return
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**************        29%%                      ]  2 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************57%%*                     ]  4 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************71%%********              ]  5 of 7 completedc:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  7 of 7 completed
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\3516324089.py:6: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   t_return = my_port.pct_change().sum()[-20:] # Calculate the yearly returns for each stock, then add up the yearly returns of each stock, then only take into account the last 20 days of data for a trailing calculation
# Ticker
# CRM      2.221777
# F        0.854633
# HPQ      1.659309
# LNVGY    1.273315
# TGT      1.767207
# TSLA     3.844955
# WMT      1.320229
# dtype: float64

# %%
## Table with 1i included.
my_port_table['Total Return'] = t_return
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM  Beta against DIA  Average Weekly Drawdown  \
# CRM            0.559584          1.325862                -8.166397
# HPQ            0.940989          1.629387                -0.931006
# LNVGY          0.607076          1.124155                -1.209171
# F              0.556419          0.704999                -0.513133
# TSLA           0.602892          1.093826               -14.738930
# WMT            1.079655          1.832894                -1.012800
# TGT            0.127681          0.440264                -5.038657
#
#        Maximum Weekly Drawdown  Total Return
# CRM                  -0.878845      2.221777
# HPQ                  -0.147306      1.659309
# LNVGY                -0.229763      1.273315
# F                    -0.105467      0.854633
# TSLA                 -3.029999      3.844955
# WMT                  -0.187992      1.320229
# TGT                  -0.793396      1.767207

# %%
## Calculation of 1j., Annualized Total Return (using trailing 10-years)

t_return_ann = ((my_port.pct_change().sum()[-20:] + 1) ** 252) - 1 
t_return_ann
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_25920\209925565.py:3: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   t_return_ann = ((my_port.pct_change().sum()[-20:] + 1) ** 252) - 1
# Ticker
# CRM      1.096663e+128
# F         3.990474e+67
# HPQ      1.100849e+107
# LNVGY     7.554528e+89
# TGT      2.480174e+111
# TSLA     4.931961e+172
# WMT       1.299527e+92
# dtype: float64

# %%
## Stock porfolio table with 1j included.
my_port_table['Annualized Total Return'] = t_return_ann
my_port_table
# Out:
#        Portfolio_Weight  Annualized Volatility  Beta against SPY  \
# CRM            0.142857               2.062737          1.269169
# HPQ            0.142857               1.740426          1.307456
# LNVGY          0.142857               1.837282          0.993005
# F              0.142857               2.364267          0.700173
# TSLA           0.142857               3.600751          0.785212
# WMT            0.142857               0.831869          2.080648
# TGT            0.142857               3.046613          0.313866
#
#        Beta against IWM  Beta against DIA  Average Weekly Drawdown  \
# CRM            0.559584          1.325862                -8.166397
# HPQ            0.940989          1.629387                -0.931006
# LNVGY          0.607076          1.124155                -1.209171
# F              0.556419          0.704999                -0.513133
# TSLA           0.602892          1.093826               -14.738930
# WMT            1.079655          1.832894                -1.012800
# TGT            0.127681          0.440264                -5.038657
#
#        Maximum Weekly Drawdown  Total Return  Annualized Total Return
# CRM                  -0.878845      2.221777            1.096663e+128
# HPQ                  -0.147306      1.659309            1.100849e+107
# LNVGY                -0.229763      1.273315             7.554528e+89
# F                    -0.105467      0.854633             3.990474e+67
# TSLA                 -3.029999      3.844955            4.931961e+172
# WMT                  -0.187992      1.320229             1.299527e+92
# TGT                  -0.793396      1.767207            2.480174e+111

# %%
## The code below was another way that we tried to calculate the Average Weekly Drawdown, 1g.

# %%
'''
## Calculation of 1g., Average Weekly Drawdown, (52-week Low minus 52-week High) / 52-week High

## First, calculate the 52 week low.

# Create an empty DataFrame to store the data
my_port_table = pd.DataFrame()


# Fetch historical data for each stock
for ticker in my_tickers:
    stock = yf.Ticker(ticker)
    historical_data = stock.history(period='1y')  # Fetch 1-year historical data
    my_port_table[ticker] = historical_data['Low']

# Calculate the 52-week low for each stock
my_port_table['52-week Low'] = my_port_table.min(axis=1)

print(my_port_table[['52-week Low']])
'''
# Out:
# "\n## Calculation of 1g., Average Weekly Drawdown, (52-week Low minus 52-week High) / 52-week High\n\n## First, calculate the 52 week low.\n\n# Create an empty DataFrame to store the data\nmy_port_table = pd.DataFrame()\n\n\n# Fetch historical data for each stock\nfor ticker in my_tickers:\n    stock = yf.Ticker(ticker)\n    historical_data = stock.history(period='1y')  # Fetch 1-year historical data\n    my_port_table[ticker] = historical_data['Low']\n\n# Calculate the 52-week low for each stock\nmy_port_table['52-week Low'] = my_port_table.min(axis=1)\n\nprint(my_port_table[['52-week Low']])\n"

# %%
'''
## Then calculate 52-week high 
# Fetch historical data for each stock
for ticker in my_tickers:
    stock = yf.Ticker(ticker)
    historical_data = stock.history(period='1y')  # Fetch 1-year historical data
    my_port_table[ticker] = historical_data['High']

# Calculate the 52-week low for each stock
my_port_table['52-week High'] = my_port_table.max(axis=1)
'''
# Out:
# "\n## Then calculate 52-week high \n# Fetch historical data for each stock\nfor ticker in my_tickers:\n    stock = yf.Ticker(ticker)\n    historical_data = stock.history(period='1y')  # Fetch 1-year historical data\n    my_port_table[ticker] = historical_data['High']\n\n# Calculate the 52-week low for each stock\nmy_port_table['52-week High'] = my_port_table.max(axis=1)\n"

# %%
'''
## Now calculate the Average Weekly Drawdown, (52-week Low minus 52-week High) / 52-week High
av__w_drawdown = ((my_port_table['52-week Low'] - my_port_table['52-week High']) / my_port_table['52-week High']) * 100
'''
# Out:
# "\n## Now calculate the Average Weekly Drawdown, (52-week Low minus 52-week High) / 52-week High\nav__w_drawdown = ((my_port_table['52-week Low'] - my_port_table['52-week High']) / my_port_table['52-week High']) * 100\n"

# %%
'''
my_port_table = pd.DataFrame(av__w_drawdown, columns=['Average Weekly Drawdown'], index=my_tickers)
my_port_table
'''
# Out:
# "\nmy_port_table = pd.DataFrame(av__w_drawdown, columns=['Average Weekly Drawdown'], index=my_tickers)\nmy_port_table\n"

# %%
## This is how we attempted to calculate the values for number 3 in the project.
'''
ETF_tickers = ['SPY', 'IWM', 'DIA']
ETF_data = yf.download(start=start_date, end=end_date, tickers=ETF_tickers)
ETF_data.head()
ETF_data = ETF_data['Adj Close']
ETF_data.head()

Port_and_ETF_data = {
    'portfolio data': my_port,
     'ETF data': ETF_data
}

All_Tickers = my_tickers.extend(ETF_tickers)
print(All_Tickers)

'''
# Out:
# "\nETF_tickers = ['SPY', 'IWM', 'DIA']\nETF_data = yf.download(start=start_date, end=end_date, tickers=ETF_tickers)\nETF_data.head()\nETF_data = ETF_data['Adj Close']\nETF_data.head()\n\nPort_and_ETF_data = {\n    'portfolio data': my_port,\n     'ETF data': ETF_data\n}\n\nAll_Tickers = my_tickers.extend(ETF_tickers)\nprint(All_Tickers)\n\n"

# %%
'''
Port_and_ETF_table = pd.DataFrame(Port_and_ETF_data)
ETF_table = pd.DataFrame(ETF_data,columns=['Adj Close'], index=ETF_tickers)
ETF_table
'''
# Out:
# "\nPort_and_ETF_table = pd.DataFrame(Port_and_ETF_data)\nETF_table = pd.DataFrame(ETF_data,columns=['Adj Close'], index=ETF_tickers)\nETF_table\n"
